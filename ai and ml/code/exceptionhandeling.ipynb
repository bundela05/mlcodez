# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year=int(input("enter dob"))
age=2025-year

try:
    if (age < 18):
        print("ok")
    else:
        raise dobException
except dobException:
    print("not ok check age")
# Out:
# not ok check age
