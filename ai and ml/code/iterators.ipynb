# %%
l1={1:"a",2:"b",3:"c",4:"d",5:"e",6:"f"}
iterator=iter(l1.values())

print(type(iterator))
print(iterator)
# Out:
# <class 'dict_valueiterator'>
# ...

# %%
try:
    print(next(iterator))
except StopIteration:
    print("no elemnt to print")
# Out:
# no elemnt to print
